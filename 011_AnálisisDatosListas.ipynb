# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/CETEC_analisis_informaci-n/blob/main/011_An%C3%A1lisisDatosListas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Listas
# ¡Bienvenidos al capítulo de Listas! Gracias por acompañarnos. :
#
# Aquí aprenderemos una forma ingeniosa de almacenar varios valores de datos. 📦 = ⚽️🏀⚾️🥎🏐🏈
#
#
#
# ![5-lists.gif](data:image/gif;base64,...)
#
#
#
#
# Supongamos que queremos crear un programa que almacene las calificaciones de los estudiantes en tareas y exámenes; necesitaríamos crear una serie de variables como esta:

# %%
#Lista de calificaciones

hw_grade1= 98
hw_grade2= 87
hw_grade3= 92
hw_grade4= 96

quiz_grade1= 9
quiz_grade2= 6
quiz_grade3= 8

# %% [markdown]
# Crear un montón de variables de esta manera es tedioso y propenso a errores. ¿Te imaginas cómo sería con más de 100 estudiantes?
#
# Las listas se utilizan para almacenar varios elementos en una sola variable.
#
# Podemos reescribir el código anterior para:

# %%
hw_grade = [98,87,92,96]
quiz_grade = [9,6,8]

# %% [markdown]
# # Instrucciones
# Crea un programa llamado comestibles.py con una comestible lista de los artículos que necesitas comprar en la tienda:
#
# * '🥚 Huevos'
# * '🥑 Aguacates'
# * '🍪 Galletas'
# * '🌶 Chiles'
# * '🫐 Arándanos'
# * '🥦 Brócoli'
#
# ¡Imprímelo comestible para asegurarte de que lo tienes!

# %%
comestibles =["🥚 Huevos","🥑 Aguacates",'🍪 Galletas','🌶 Chiles','🫐 Arándanos','🥦 Brócoli']
print(comestibles)
# Out:
# ['🥚 Huevos', '🥑 Aguacates', '🍪 Galletas', '🌶 Chiles', '🫐 Arándanos', '🥦 Brócoli']

# %%
vocales= ["a","e","i","o","u"]
#Index     0.  1.  2.  3.  4

# %%
print(vocales[1])
# Out:
# e

# %%
vocales= ["a","e","i","o","u"]
#Index     0.  1.  2.  3.  4
#Index.   -5. -4. -3. -2. -1

# %%
print(vocales[0:3])
print(vocales[1:3])
# Out:
# ['a', 'e', 'i']
# ['e', 'i']

# %% [markdown]
# #Instruciones
# Crea un programa `todo.py` que defina una lista de tareas con los siguientes elementos:
#
# * '🏦 Conseguir monedas.'
#
# * '🧺 Lavar la ropa.'
#
# * '🌳 Dar un paseo.'
#
# * '💈 Cortarme el pelo.'
#
# * '🍵 Prepararme un té.'
#
# * '💻 Completar el capítulo de Listas.'
#
# * '💖 Llamar a mamá.'
#
# * '📺 Ver My Hero Academia.'
#
# Imprime el primer elemento y el segundo. ¿Qué obtuviste?
#
# A continuación, usa la segmentación para imprimir el tercer, cuarto y quinto elemento.
#
# Intenta imprimir el elemento en el índice 9 para ver el error de índice antes de continuar.
