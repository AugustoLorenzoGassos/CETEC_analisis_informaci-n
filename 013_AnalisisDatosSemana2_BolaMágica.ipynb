# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/CETEC_analisis_informaci-n/blob/main/013_AnalisisDatosSemana2_BolaM%C3%A1gica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crea un programa que plique el comportamiento de la bola mágina utilizando las siguientes respuestas
#
# *Si definitivamemnte si
# *Es definitivamente así
# *Sin duda
# *Respuesta confusa, intenta otra vez
# *Preguntga de nuevo más tarde
# *Mejor no decirte ahota
# *Mis fuentes dicen que no
# *Las probabilidades no son muy buenas
# *Muy dudoso
#
# EL progama debe recibir una pregunta del usuario y arrojar una respuesta aleatoria

# %%
lista_respuestas = ['Si definitivamemnte si',
'Es definitivamente así',
'Sin duda',
'Respuesta confusa, intenta otra vez',
'Preguntga de nuevo más tarde',
'Mejor no decirte ahota',
'Mis fuentes dicen que no',
'Las probabilidades no son muy buenas',
'Muy dudoso']

Pregunta = input("Escribe uan pregunta: ")
Respuesta = rd.randint(0,8)
print(lista_respuestas[Respuesta])
# Out:
# Escribe uan pregunta: Voy a aprobar el diplomado?
# Las probabilidades no son muy buenas

# %%
Pregunta = input("Escribe uan pregunta: ")
Respuesta = rd.randint(1,9)
if Respuesta == 1:
  print("Si definitivamemnte si")
elif Respuesta == 2:
  print("Es definitivamente así")
elif Respuesta == 3:
  print("Sin duda")
elif Respuesta == 4:
  print("Respuesta confusa, intenta otra vez")
elif Respuesta == 5:
  print("Preguntga de nuevo más tarde")
elif Respuesta == 6:
  print("Mejor no decirte ahota")
elif Respuesta == 7:
  print("Mis fuentes dicen que no")
elif Respuesta == 8:
  print("Las probabilidades no son muy buenas")
elif Respuesta == 9:
  print("Muy dudoso")
# Out:
# Escribe uan pregunta: Voy a aprobar el diplomado?
# Respuesta confusa, intenta otra vez
