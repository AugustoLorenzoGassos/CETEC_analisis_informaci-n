# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/CETEC_analisis_informaci-n/blob/main/007_AnalisisDatosFuncciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones
# A medida que nuestro código se vuelve más y más largo, es posible que te encuentres copiando y pegando un bloque de código específico en diferentes partes del programa. ¡Eso no es bueno!
#
# “No te repitas” (DRY, por sus siglas en inglés) es un principio del desarrollo de software que busca reducir la repetición y escribir código limpio y de calidad. Las funciones desempeñan un papel fundamental.
#
#
#
# ![6-functions.gif](data:image/gif;base64,...)
#
#
# Una función es un bloque de código reutilizable que realiza una tarea específica. Para ejecutar este bloque de código, solo necesitas escribir el nombre de la función, seguido de un par de paréntesis ( ).
#
# Ya sea que la tarea consista en cinco o veinte líneas de código, puedes incluirlas en una función y utilizarlas posteriormente en cualquier parte de tu programa. Requiere un poco más de esfuerzo al principio, pero a la larga te ahorrará mucho tiempo.
#
# ¡Giro inesperado! En este curso, hemos estado usando funciones todo el tiempo. 🧩
#
# Las funciones integradas son 68 funciones que vienen con el intérprete de Python y que están disponibles para su uso. Aquí hay algunas que quizás reconozcas:
#
# * print()
# * input()
# * len()
#
# Ya los habíamos usado antes, pero no profundizamos en cómo funcionan internamente.
#
# ¡Y eso está bien! Esa es la gran ventaja de las funciones integradas. Al igual que con un coche, no necesitas saber qué hay debajo del capó para manejarlo.
#
# ¡Veamos algunas funciones integradas de Python!

# %% [markdown]
# #Instrucciones
#
# Crea un programa dry.py y consulta la lista completa de funciones integradas :
#
# Encuentra 4 funciones integradas que hayamos utilizado anteriormente en el curso.
# Elige una función integrada que no hayamos visto antes.
# Utilice cada uno de estos elementos una sola vez en el programa.
#
# Para la nueva función, intenta leer la documentación (😵‍💫) o búscala en Google (👍).
#
# Añade un comentario para cada función integrada para explicar cómo funciona.

# %%
def saludo():
  print("Hola")
  print("¿Como estas?")

saludo()
saludo()
saludo()
# Out:
# Hola
# ¿Como estas?
# Hola
# ¿Como estas?
# Hola
# ¿Como estas?

# %% [markdown]
# # Instrucciones
#
#
# La galleta de la fortuna es una pequeña galleta tipo oblea con un papelito en su interior, llamado "fortuna", que suele ser una frase china con su traducción y una lista de números de la suerte. Se sirven en restaurantes de Estados Unidos y Canadá. 🥠
#
# Crea un programa llamado fortune_cookie.py que le dé al usuario mensajes de la fortuna aleatorios.
#
# Define una función llamada fortune(). Dentro de la función, imprime una predicción aleatoria de la lista de opciones que aparece a continuación:
#
# * No persigas la felicidad, créala.
#
# * Todas las cosas son difíciles antes de ser fáciles.
#
# * Al que madruga, Dios lo ayuda... pero el segundo ratón es el que se queda con el queso.
#
# * Alguien en tu vida necesita una carta tuya.
#
# * No te limites a pensar. ¡Actúa!
#
# * Tu corazón dará un vuelco.
#
# * La fortuna que buscas está en otra galleta.
#
# * ¡Ayuda! ¡Estoy prisionero en una panadería china!
#
# Asegúrese de usar el randommódulo random.randint() y un if/ elif/ else.
#
# Luego, llama a la fortune() función tres veces y ¡mira qué obtienes!
#
# Extra: Si te atreves, reescribe la función sin una if/ elif/ else.
