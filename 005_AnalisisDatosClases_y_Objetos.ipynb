# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/CETEC_analisis_informaci-n/blob/main/005_AnalisisDatosClases_y_Objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lists with student id, name, year, gpa, and enrolled status

student_1 = [1001, 'Asiqur', 10, 3.7, True]
student_2 = [1002, 'Jerry', 9, 3.8, True]
student_3 = [1003, 'Rose', 12, 3.6, False]

# %%
class Student:
  student_id=0
  name = ""
  year = 0
  gpa = 0.0
  enrolled = False

cetec = Student()
cetec.student_id = 1113
cetec.name = "Centro de estudios de computación"
cetec.year = 11
cetec.gpa = 4.0
cetec.enrolled = True

print(vars(cetec))
# Out:
# {'student_id': 1113, 'name': 'Centro de estudios de computación', 'year': 11, 'gpa': 4.0, 'enrolled': True}

# %% [markdown]
# # Instrucciones
#
# ![7-classes.gif](data:image/gif;base64,...)
#
# Supongamos que estamos creando una aplicación de entrega de comida y queremos almacenar la información de los restaurantes. 🍽️
#
# Crea una Restaurantclase en un archivo restaurants.py con los siguientes atributos:
#
# * name del tipo str
# * category del tipo str
# * rating del tipo float
# * delivery del tipo bool
#
# Deje estos valores vacíos/predeterminados por ahora.
#
# No debería ocurrir nada al ejecutar el código, ya que aún no hemos utilizado esta clase. ¡En el próximo ejercicio comenzaremos a usarla!

# %%
# Instrucciones
class RestaurantClase:
  name = ""
  category = ""
  rating = 0.0
  delivery = False

# %% [markdown]
# Instrucciones
# En el último ejercicio, creamos una Restaurantclase.
#
# En un nuevo archivo llamado bobs_burgers.py , crea una instancia de la Restaurantclase bobs_burgerscon los siguientes atributos:
#
# 'Bob's Burgers'
# 'American Diner'
# 4.7
# False
# Una vez hecho esto, crea dos instancias más de la Restaurantclase con tus restaurantes favoritos cerca.
#
# Luego, ¡úsalo print(vars())para mostrar cada uno de los tres restaurantes!

# %%
bobs_burgers = RestaurantClase()
bobs_burgers.name = "Bob's Burgers"
bobs_burgers.category = "American Dinner"
bobs_burgers.rating = 4.7
bobs_burgers.delivery = False

print(vars(bobs_burgers))
# Out:
# {'name': "Bob's Burgers", 'category': 'American Dinner', 'rating': 4.7, 'delivery': False}

# %%
class Student:
  def __init__(self, name, year, gpa, enrolled):
    self.name = name
    self.year = year
    self.gpa = gpa
    self.enrolles = enrolled

Daniel = Student("Daniel",10,4.0,True)
print(vars(Daniel))
# Out:
# {'name': 'Daniel', 'year': 10, 'gpa': 4.0, 'enrolles': True}

# %% [markdown]
# Instrucciones
# Crea un programa llamado favorite_cities.py .
#
# Vamos a crear una Cityclase que utilice el init()método para definir los siguientes atributos:
#
# name (Nombre de la ciudad)
# contry (País)
# population (Población)
# landmarks (Puntos de interes) A continuación, crea un objeto para tu ciudad natal y asígnale los atributos mencionados anteriormente.
# Por último, ¡crea otro objeto para la ciudad que siempre has querido visitar!
#
# Extra: Añade 2 o 3 atributos más, como apodo, año de fundación, alcalde, etc.

# %%
class Cityclass:
  def __init__(self, name, country,population,landmarks,gentilicio):
    self.name = name
    self.country = country
    self.population = population
    self.landmarks = landmarks
    self.gentilicio = gentilicio

ciudad_natal = Cityclass("Xalapa","México",488531,"Paseo de los lagos, museo de antropología","Xalapaños")
ciudad_conocer = Cityclass("Tepic","México",425924,"Playas","nayarita" )

print("Ciudad natal: ",vars(ciudad_natal))
print("Ciudad que me gustaría conocer: ", vars(ciudad_conocer))
# Out:
# Ciudad natal:  {'name': 'Xalapa', 'country': 'México', 'population': 488531, 'landmarks': 'Paseo de los lagos, museo de antropología', 'gentilicio': 'Xalapaños'}
# Ciudad que me gustaría conocer:  {'name': 'Tepic', 'country': 'México', 'population': 425924, 'landmarks': 'Playas', 'gentilicio': 'nayarita'}
