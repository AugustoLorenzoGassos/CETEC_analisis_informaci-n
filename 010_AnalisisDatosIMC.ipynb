# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/CETEC_analisis_informaci-n/blob/main/010_AnalisisDatosIMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Peso = 89
Altura = 1.93

IMC = Peso/Altura**2

print(IMC)
